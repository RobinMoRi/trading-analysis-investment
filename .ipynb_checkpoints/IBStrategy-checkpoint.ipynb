# %% [markdown]
# # Investment strategy weight by premium/rebate

# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math
from yahoofinancials import YahooFinancials
import lxml.html as lh
import lxml.etree as etree
from selenium import webdriver
from requests.utils import quote
import time
import re
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read configuration file

# %%
# Read df and set nan to empty string
stocks_df = pd.read_csv('ib_stocks_stockholm.csv')
stocks_df.fillna('', inplace=True)

# List of stocks
stocks_list = stocks_df['Ticker'].tolist()

# Get url-ending list
url_ending_list = stocks_df['URL_PATH'].tolist()

# Get element-name list
element_names = stocks_df['ELEMENT_NAME'].tolist()

# Comply with format of yahoo finance for swedish stocks
stocks_df['Ticker'] = stocks_df['Ticker'].str.replace(' ','-')
stocks_df['Ticker'] = stocks_df['Ticker'].astype(str) + '.ST'
stocks_list_yf = stocks_df['Ticker'].tolist()

# %% [markdown]
# ### Read current stock price from yahoo financials

# %%
yahoo_financials_ib = YahooFinancials(stocks_list_yf)
current_price = yahoo_financials_ib.get_current_price()
current_price
# Out:
# {'BURE.ST': 210.2,
#  'AJA-B.ST': 265,
#  'CRED-A.ST': 77.45,
#  'FASTAT.ST': 12.94,
#  'FIRST-B.ST': 5.25,
#  'FLAT-B.ST': 8.41,
#  'HAV-B.ST': 18,
#  'INDU-C.ST': 231.4,
#  'INVE-B.ST': 172.58,
#  'KDEV.ST': 2.6,
#  'KINV-B.ST': 166.9,
#  'LATO-B.ST': 206.7,
#  'LINC.ST': 61.55,
#  'LUND-B.ST': 426,
#  'NAXS.ST': 55.7,
#  'NAIG-B.ST': 6.099,
#  'SVOL-B.ST': 53.39,
#  'TRAC-B.ST': 231,
#  'VEFAB.ST': 2.37,
#  'VNV.ST': 24.92,
#  'ORES.ST': 103.6}

# %% [markdown]
# ### Crawl pages to read reported and computed rebate/premium values

# %%
driver = webdriver.Firefox()
driver.set_page_load_timeout(10)

base_url='https://ibindex.se/ibi/#/'
html_pages = {}
for index, url_ending in enumerate(url_ending_list):
    driver.get(f'{base_url}{quote(url_ending)}')
    driver.refresh()
    time.sleep(4)
    html = driver.page_source
    html_pages[stocks_list[index]] = html
driver.quit()

# %% [markdown]
# ### Create data structure for calculated and reported rebate/premiums sorted by stocks

# %%
rebate_premium_dict = {}
regexp_number = '(\d{1,2}.\d{1,2})'
regexp_rebate_premium = '(rabatt|premie)'

for index, symbol in enumerate(stocks_list):
    doc = lh.fromstring(html_pages[symbol])
    if(element_names[index] != ''):
        rebate_premium_list = doc.xpath(f'//{element_names[index]}//span')
    else:
        rebate_premium_list = doc.xpath('//app-company-current-rebate-premium//span')
    vals = [el.text for el in rebate_premium_list]
    if(len(vals) == 6):
        val1 = float(re.search(regexp_number, vals[1]).group(1))
        val2 = float(re.search(regexp_number, vals[4]).group(1))
        valtype1 = re.search(regexp_rebate_premium, vals[2]).group(1)
        valtype2 = re.search(regexp_rebate_premium, vals[5]).group(1)
    else:
        val1 = 0
        val2 = 0
        valtype1 = 'premium'
        valtype2 = 'premium'
          
    computed_dict = {
        'val': val1,
        'type': valtype1
    }
    reported_dict = {
        'val': val2,
        'type': valtype2
    }
    rebate_premium_dict[symbol] = {'computed': computed_dict, 'reported': reported_dict}

# %% [markdown]
# ### Create dataframe

# %%
my_columns = ['Ticker', 'Price', 'Reported Val', 'Reported Type', 'Reported Weight','Reported Position', 'Computed Val', 'Computed Type', 'Computed Weight','Computed Position', 'Rep Buy', 'Comp Buy']
final_dataframe = pd.DataFrame(columns = my_columns)

for idx, symbol_yf in enumerate(stocks_list_yf):
    symbol = stocks_list[idx]
    computed_val = rebate_premium_dict[symbol]['computed']['val']
    computed_type = rebate_premium_dict[symbol]['computed']['type']
    reported_val = rebate_premium_dict[symbol]['reported']['val']
    reported_type = rebate_premium_dict[symbol]['reported']['type']
    series_list = [symbol, current_price[symbol_yf], reported_val, reported_type, 'N/A', 'N/A', computed_val, computed_type, 'N/A', 'N/A', 'N/A', 'N/A']
    panda_series = pd.Series(series_list, index = my_columns)
    final_dataframe = final_dataframe.append(panda_series, ignore_index=True)

reported_sum = 0
computed_sum = 0
for index, row in final_dataframe.iterrows():
    if(row['Reported Type'] == 'rabatt'):
        reported_sum += row['Reported Val']
    if(row['Computed Type'] == 'rabatt'):
        computed_sum += row['Computed Val']

final_dataframe['Reported Weight'] = final_dataframe['Reported Val']/reported_sum
final_dataframe.loc[final_dataframe['Reported Type'] == 'premie', 'Reported Weight'] = 0 
final_dataframe['Computed Weight'] = final_dataframe['Computed Val']/computed_sum
final_dataframe.loc[final_dataframe['Computed Type'] == 'premie', 'Computed Weight'] = 0
# Out:
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)
# /var/folders/xv/b12365j13k53z5vt7sn5rg4m0000gn/T/ipykernel_65877/1488962063.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(panda_series, ignore_index=True)

# %% [markdown]
# ### Input portfolio size

# %%
portfolio_size = input("Enter the value of your portfolio:")

try:
    val = float(portfolio_size)
except ValueError:
    print("That's not a number! \n Try again:")
    portfolio_size = input("Enter the value of your portfolio:")
# Out:
# Enter the value of your portfolio:5000

# %% [markdown]
# ### Compute position to the different stocks

# %%
final_dataframe['Reported Position'] = final_dataframe['Reported Weight']*val
final_dataframe['Computed Position'] = final_dataframe['Computed Weight']*val

# %% [markdown]
# ### Create final dataframe

# %%
def colorMap(val):
    if val == 'rabatt':
        color = 'green'
    elif val == 'premie':
        color = 'red'
    else:
        color = 'black'
    return ['color: %s' % color] * len(val)

# Buy
final_dataframe['Comp Buy'] = final_dataframe['Computed Position']/final_dataframe['Price']
final_dataframe['Comp Buy'] = final_dataframe['Comp Buy'].apply(np.floor)

final_dataframe['Rep Buy'] = final_dataframe['Reported Position']/final_dataframe['Price']
final_dataframe['Rep Buy'] = final_dataframe['Rep Buy'].apply(np.floor)
final_dataframe.style.applymap(colorMap)
# Out:
# <style type="text/css">
# #T_5647f_row0_col0, #T_5647f_row0_col1, #T_5647f_row0_col2, #T_5647f_row0_col4, #T_5647f_row0_col5, #T_5647f_row0_col6, #T_5647f_row0_col8, #T_5647f_row0_col9, #T_5647f_row0_col10, #T_5647f_row0_col11, #T_5647f_row1_col0, #T_5647f_row1_col1, #T_5647f_row1_col2, #T_5647f_row1_col4, #T_5647f_row1_col5, #T_5647f_row1_col6, #T_5647f_row1_col8, #T_5647f_row1_col9, #T_5647f_row1_col10, #T_5647f_row1_col11, #T_5647f_row2_col0, #T_5647f_row2_col1, #T_5647f_row2_col2, #T_5647f_row2_col4, #T_5647f_row2_col5, #T_5647f_row2_col6, #T_5647f_row2_col8, #T_5647f_row2_col9, #T_5647f_row2_col10, #T_5647f_row2_col11, #T_5647f_row3_col0, #T_5647f_row3_col1, #T_5647f_row3_col2, #T_5647f_row3_col4, #T_5647f_row3_col5, #T_5647f_row3_col6, #T_5647f_row3_col8, #T_5647f_row3_col9, #T_5647f_row3_col10, #T_5647f_row3_col11, #T_5647f_row4_col0, #T_5647f_row4_col1, #T_5647f_row4_col2, #T_5647f_row4_col4, #T_5647f_row4_col5, #T_5647f_row4_col6, #T_5647f_row4_col8, #T_5647f_row4_col9, #T_5647f_row4_col10, #T_5647f_row4_col11, #T_5647f_row5_col0, #T_5647f_row5_col1, #T_5647f_row5_col2, #T_5647f_row5_col4, #T_5647f_row5_col5, #T_5647f_row5_col6, #T_5647f_row5_col8, #T_5647f_row5_col9, #T_5647f_row5_col10, #T_5647f_row5_col11, #T_5647f_row6_col0, #T_5647f_row6_col1, #T_5647f_row6_col2, #T_5647f_row6_col3, #T_5647f_row6_col4, #T_5647f_row6_col5, #T_5647f_row6_col6, #T_5647f_row6_col7, #T_5647f_row6_col8, #T_5647f_row6_col9, #T_5647f_row6_col10, #T_5647f_row6_col11, #T_5647f_row7_col0, #T_5647f_row7_col1, #T_5647f_row7_col2, #T_5647f_row7_col4, #T_5647f_row7_col5, #T_5647f_row7_col6, #T_5647f_row7_col8, #T_5647f_row7_col9, #T_5647f_row7_col10, #T_5647f_row7_col11, #T_5647f_row8_col0, #T_5647f_row8_col1, #T_5647f_row8_col2, #T_5647f_row8_col4, #T_5647f_row8_col5, #T_5647f_row8_col6, #T_5647f_row8_col8, #T_5647f_row8_col9, #T_5647f_row8_col10, #T_5647f_row8_col11, #T_5647f_row9_col0, #T_5647f_row9_col1, #T_5647f_row9_col2, #T_5647f_row9_col4, #T_5647f_row9_col5, #T_5647f_row9_col6, #T_5647f_row9_col8, #T_5647f_row9_col9, #T_5647f_row9_col10, #T_5647f_row9_col11, #T_5647f_row10_col0, #T_5647f_row10_col1, #T_5647f_row10_col2, #T_5647f_row10_col4, #T_5647f_row10_col5, #T_5647f_row10_col6, #T_5647f_row10_col8, #T_5647f_row10_col9, #T_5647f_row10_col10, #T_5647f_row10_col11, #T_5647f_row11_col0, #T_5647f_row11_col1, #T_5647f_row11_col2, #T_5647f_row11_col4, #T_5647f_row11_col5, #T_5647f_row11_col6, #T_5647f_row11_col8, #T_5647f_row11_col9, #T_5647f_row11_col10, #T_5647f_row11_col11, #T_5647f_row12_col0, #T_5647f_row12_col1, #T_5647f_row12_col2, #T_5647f_row12_col4, #T_5647f_row12_col5, #T_5647f_row12_col6, #T_5647f_row12_col8, #T_5647f_row12_col9, #T_5647f_row12_col10, #T_5647f_row12_col11, #T_5647f_row13_col0, #T_5647f_row13_col1, #T_5647f_row13_col2, #T_5647f_row13_col4, #T_5647f_row13_col5, #T_5647f_row13_col6, #T_5647f_row13_col8, #T_5647f_row13_col9, #T_5647f_row13_col10, #T_5647f_row13_col11, #T_5647f_row14_col0, #T_5647f_row14_col1, #T_5647f_row14_col2, #T_5647f_row14_col4, #T_5647f_row14_col5, #T_5647f_row14_col6, #T_5647f_row14_col8, #T_5647f_row14_col9, #T_5647f_row14_col10, #T_5647f_row14_col11, #T_5647f_row15_col0, #T_5647f_row15_col1, #T_5647f_row15_col2, #T_5647f_row15_col4, #T_5647f_row15_col5, #T_5647f_row15_col6, #T_5647f_row15_col8, #T_5647f_row15_col9, #T_5647f_row15_col10, #T_5647f_row15_col11, #T_5647f_row16_col0, #T_5647f_row16_col1, #T_5647f_row16_col2, #T_5647f_row16_col4, #T_5647f_row16_col5, #T_5647f_row16_col6, #T_5647f_row16_col8, #T_5647f_row16_col9, #T_5647f_row16_col10, #T_5647f_row16_col11, #T_5647f_row17_col0, #T_5647f_row17_col1, #T_5647f_row17_col2, #T_5647f_row17_col4, #T_5647f_row17_col5, #T_5647f_row17_col6, #T_5647f_row17_col8, #T_5647f_row17_col9, #T_5647f_row17_col10, #T_5647f_row17_col11, #T_5647f_row18_col0, #T_5647f_row18_col1, #T_5647f_row18_col2, #T_5647f_row18_col4, #T_5647f_row18_col5, #T_5647f_row18_col6, #T_5647f_row18_col8, #T_5647f_row18_col9, #T_5647f_row18_col10, #T_5647f_row18_col11, #T_5647f_row19_col0, #T_5647f_ro ...
#   color: black;
# }
# #T_5647f_row0_col3, #T_5647f_row1_col3, #T_5647f_row1_col7, #T_5647f_row3_col3, #T_5647f_row3_col7, #T_5647f_row4_col3, #T_5647f_row4_col7, #T_5647f_row5_col3, #T_5647f_row5_col7, #T_5647f_row7_col3, #T_5647f_row7_col7, #T_5647f_row8_col3, #T_5647f_row8_col7, #T_5647f_row9_col3, #T_5647f_row9_col7, #T_5647f_row10_col3, #T_5647f_row10_col7, #T_5647f_row13_col3, #T_5647f_row13_col7, #T_5647f_row14_col3, #T_5647f_row14_col7, #T_5647f_row15_col3, #T_5647f_row15_col7, #T_5647f_row17_col3, #T_5647f_row17_col7, #T_5647f_row18_col3, #T_5647f_row18_col7, #T_5647f_row19_col3, #T_5647f_row19_col7, #T_5647f_row20_col3, #T_5647f_row20_col7 {
#   color: green;
# }
# #T_5647f_row0_col7, #T_5647f_row2_col3, #T_5647f_row2_col7, #T_5647f_row11_col3, #T_5647f_row11_col7, #T_5647f_row12_col3, #T_5647f_row12_col7, #T_5647f_row16_col3, #T_5647f_row16_col7 {
#   color: red;
# }
# </style>
# <table id="T_5647f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5647f_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_5647f_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_5647f_level0_col2" class="col_heading level0 col2" >Reported Val</th>
#       <th id="T_5647f_level0_col3" class="col_heading level0 col3" >Reported Type</th>
#       <th id="T_5647f_level0_col4" class="col_heading level0 col4" >Reported Weight</th>
#       <th id="T_5647f_level0_col5" class="col_heading level0 col5" >Reported Position</th>
#       <th id="T_5647f_level0_col6" class="col_heading level0 col6" >Computed Val</th>
#       <th id="T_5647f_level0_col7" class="col_heading level0 col7" >Computed Type</th>
#       <th id="T_5647f_level0_col8" class="col_heading level0 col8" >Computed Weight</th>
#       <th id="T_5647f_level0_col9" class="col_heading level0 col9" >Computed Position</th>
#       <th id="T_5647f_level0_col10" class="col_heading level0 col10" >Rep Buy</th>
#       <th id="T_5647f_level0_col11" class="col_heading level0 col11" >Comp Buy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5647f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5647f_row0_col0" class="data row0 col0" >BURE</td>
#       <td id="T_5647f_row0_col1" class="data row0 col1" >210.200000</td>
#       <td id="T_5647f_row0_col2" class="data row0 col2" >10.320000</td>
#       <td id="T_5647f_row0_col3" class="data row0 col3" >rabatt</td>
#       <td id="T_5647f_row0_col4" class="data row0 col4" >0.020346</td>
#       <td id="T_5647f_row0_col5" class="data row0 col5" >101.728999</td>
#       <td id="T_5647f_row0_col6" class="data row0 col6" >4.770000</td>
#       <td id="T_5647f_row0_col7" class="data row0 col7" >premie</td>
#       <td id="T_5647f_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_5647f_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_5647f_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_5647f_row0_col11" class="data row0 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5647f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5647f_row1_col0" class="data row1 col0" >AJA B</td>
#       <td id="T_5647f_row1_col1" class="data row1 col1" >265</td>
#       <td id="T_5647f_row1_col2" class="data row1 col2" >21.360000</td>
#       <td id="T_5647f_row1_col3" class="data row1 col3" >rabatt</td>
#       <td id="T_5647f_row1_col4" class="data row1 col4" >0.042111</td>
#       <td id="T_5647f_row1_col5" class="data row1 col5" >210.555369</td>
#       <td id="T_5647f_row1_col6" class="data row1 col6" >12.910000</td>
#       <td id="T_5647f_row1_col7" class="data row1

# %% [markdown]
# ### Plot distribution of stocks to buy - Reported Rebate

# %%
labels = []
sizes = []
stocks_count = 0
for index, row in final_dataframe.iterrows():
    if(row['Rep Buy'] != 0):
        labels.append(row['Ticker'])
        sizes.append(row['Rep Buy']*row['Price'])
        stocks_count += row['Rep Buy']

fig, ax = plt.subplots(figsize=(15, 8), subplot_kw=dict(aspect="equal"))
#ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

wedges, texts = ax.pie(sizes, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(sizes[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.legend(wedges, labels, title="Stocks", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
ax.set_title('Buy proportions')

plt.show()

data = {'Budget': [val], 'Buy Sum': [sum(sizes)], 'Money left': [val-sum(sizes)], 'Total shares to buy': [stocks_count], 'Company count': [len(sizes)]}
print(pd.DataFrame.from_dict(data))
# Out:
#    Budget   Buy Sum  Money left  Total shares to buy  Company count
# 0  5000.0  3916.391    1083.609                  655             11
